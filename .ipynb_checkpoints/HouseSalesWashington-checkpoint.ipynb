# %% [markdown]
# # ADS500B
# ## House Sales Washington
#
# This dataset contains details of house sales in neighborhoods of King County, Washington.
# It includes data for houses sold between May 2014 and May 2015.
#
# Origin: Kaggle
# File Type: CSV
# File Size: 2.5 MB
# Modeling Problem: Regression
# Missing Values: Yes
#
# Attributes:
# id - a numerical identity field for each house sale
#
# date - date when the house is sold
#
# price - house sale price amount in US dollars (dependent variable)
#
# bedrooms - number of bedrooms in the house
#
# bathrooms - number of bathrooms in the house
#
# sqft_living - living area in square feet
#
# sqft_lot - total lot area in square feet
#
# floors - number of floors in the house
#
# waterfront - binary field, 1 if the house has a waterfront, 0 for no waterfront
#
# view - binary field, 1 if the house has a view, 0 for no view
#
# condition - a number denoting the condition of the house
#
# grade - a number denoting the grade of the house
#
# sqft_basement - area in square feet if the house has a basement
#
# yr_built - in which year is the house built
#
# yr_renovated - year when a house is renovated, 0 if not renovated
#
# zipcode - house location zipcode in the county
#
# lat - latitude cooridnate
#
# long - longitude coordinate

# %% [markdown]
# # Section 1 - Data Importing and Pre-processin

# %% [markdown]
# ## Import dataset and describe characteristics such as dimensions, data types, file types, and import methods used

# %%
#Dependencies
import numpy as np
import pandas as pd
import csv
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Data is stored in a CSV, it is imported in to a DataFrame using read_csv, no arguments where required

# %%
#Read CSV to DF
houseSalesDF = pd.read_csv('house_sales.csv')
houseSalesDF
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0           1180.0    5650.0     1.0           0     0  ...      7
# 1           2570.0    7242.0     2.0           0     0  ...      7
# 2            770.0   10000.0     1.0           0     0  ...      6
# 3           1960.0    5000.0     1.0           0     0  ...      7
# 4           1680.0    8080.0     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608       1530.0    1131.0     3.0           0     0  ...      8
# 21609       2310.0    5813.0     2.0           0     0  ...      8
# 21610       1020.0    1350.0     2.0           0     0  ...      7
# 21611       1600.0    2388.0     2.0           0     0  ...      8
# 21612       1020.0    1076.0     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %% [markdown]
# *Bedrooms* and *Date* are converted to proper Datatypes

# %%
#Check duplicate values
duplicate = houseSalesDF[houseSalesDF.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# There is no duplicate value in the dataset

# %%
#Convert bedrooms to int
houseSalesDF['bedrooms'] = houseSalesDF['bedrooms'].astype('Int64')

# %%
#Convert Date columne to Datetime date type
houseSalesDF.loc[:,'date'] = pd.to_datetime(houseSalesDF.loc[:,'date'])

# %%
#Checking the data types
houseSalesDF.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  Int64
# bathrooms               float64
# sqft_living             float64
# sqft_lot                float64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %%
#Count of variables by data type
houseSalesDF.dtypes.value_counts()
# Out:
# int64             12
# float64            7
# datetime64[ns]     1
# Int64              1
# dtype: int64

# %%
#Shape of initial data set
dfShape = houseSalesDF.shape
print('Housing DF -> ' + str(dfShape[0]) + ' row, and ' + str(dfShape[1]) + ' columns' )
# Out:
# Housing DF -> 21613 row, and 21 columns

# %%
#Checking the missing/null values
houseSalesDF.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms         1134
# bathrooms        1068
# sqft_living      1110
# sqft_lot         1044
# floors              0
# waterfront          0
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#Checking percantage of null values
round(houseSalesDF.isnull().sum() / dfShape[0] *100,2)
# Out:
# id               0.00
# date             0.00
# price            0.00
# bedrooms         5.25
# bathrooms        4.94
# sqft_living      5.14
# sqft_lot         4.83
# floors           0.00
# waterfront       0.00
# view             0.00
# condition        0.00
# grade            0.00
# sqft_above       0.00
# sqft_basement    0.00
# yr_built         0.00
# yr_renovated     0.00
# zipcode          0.00
# lat              0.00
# long             0.00
# sqft_living15    0.00
# sqft_lot15       0.00
# dtype: float64

# %%
houseSalesDF["view"].unique()
# Out:
# array([0, 3, 4, 2, 1])

# %% [markdown]
# as we know the view column should be a binary field. 0 and 1. The rest of the values are considered as outlier.

# %%
housesFloat.describe()
# Out:
#               price     bathrooms   sqft_living      sqft_lot        floors  \
# count  2.161300e+04  20545.000000  20503.000000  2.056900e+04  21613.000000
# mean   5.400881e+05      2.113507   2081.073697  1.517982e+04      1.494309
# std    3.671272e+05      0.768913    915.043176  4.148617e+04      0.539989
# min    7.500000e+04      0.000000    290.000000  5.200000e+02      1.000000
# 25%    3.219500e+05      1.500000   1430.000000  5.040000e+03      1.000000
# 50%    4.500000e+05      2.250000   1920.000000  7.620000e+03      1.500000
# 75%    6.450000e+05      2.500000   2550.000000  1.070800e+04      2.000000
# max    7.700000e+06      8.000000  12050.000000  1.651359e+06      3.500000
#
#                 lat          long
# count  21613.000000  21613.000000
# mean      47.560053   -122.213896
# std        0.138564      0.140828
# min       47.155900   -122.519000
# 25%       47.471000   -122.328000
# 50%       47.571800   -122.230000
# 75%       47.678000   -122.125000
# max       47.777600   -121.315000

# %%
houseSalesDF.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  20479.000000  20545.000000  20503.000000
# mean   4.580302e+09  5.400881e+05      3.372821      2.113507   2081.073697
# std    2.876566e+09  3.671272e+05      0.930711      0.768913    915.043176
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.500000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1920.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  12050.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.056900e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.517982e+04      1.494309      0.007542      0.234303      3.409430
# std    4.148617e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.620000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.070800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# ## Clean, wrangle, and handle missing data

# %% [markdown]
# as we can see we have missing values for bedrooms, bathrooms, sqft_living, and sqft_lot.

# %%
# dropping unnecessary attributes
houseSalesDF.drop(columns=['id'],inplace=True)
houseSalesDF
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00       1180.0    5650.0
# 1     2014-12-09  538000.0         3       2.25       2570.0    7242.0
# 2     2015-02-25  180000.0         2       1.00        770.0   10000.0
# 3     2014-12-09  604000.0         4       3.00       1960.0    5000.0
# 4     2015-02-18  510000.0         3       2.00       1680.0    8080.0
# ...          ...       ...       ...        ...          ...       ...
# 21608 2014-05-21  360000.0         3       2.50       1530.0    1131.0
# 21609 2015-02-23  400000.0         4       2.50       2310.0    5813.0
# 21610 2014-06-23  402101.0         2       0.75       1020.0    1350.0
# 21611 2015-01-16  400000.0         3       2.50       1600.0    2388.0
# 21612 2014-10-15  325000.0         2       0.75       1020.0    1076.0
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0         1.0           0     0          3      7        1180              0
# 1         2.0           0     0          3      7        2170            400
# 2         1.0           0     0          3      6         770              0
# 3         1.0           0     0          5      7        1050            910
# 4         1.0           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21608     3.0           0     0          3      8        1530              0
# 21609     2.0           0     0          3      8        2310              0
# 21610     2.0           0     0          3      7        1020              0
# 21611     2.0           0     0          3      8        1600              0
# 21612     2.0           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# ...         ...           ...      ...      ...      ...            ...
# 21608      2009             0    98103  47.6993 -122.346           1530
# 21609      2014             0    98146  47.5107 -122.362           1830
# 21610      2009             0    98144  47.5944 -122.299           1020
# 21611      2004             0    98027  47.5345 -122.069           1410
# 21612      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 2            8062
# 3            5000
# 4            7503
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [21613 rows x 20 columns]

# %% [markdown]
# # Handling missing values
#
#
# There are various methods to fix the missing values. We could fill them with mean, median, or mode,
# which I think this is the best option. Another approach is to remove the rows that they contained with missing values.
# There are other methods as well, which I think it's not necessary for this dataset. feel free to share your thoughts.
#
# ## ss
# nulls are around 5% of the data we may want to concder removing them, if we see in the histogram we have outliers

# %%
#Removing missing values
houseSalesDF = houseSalesDF.dropna(how='any')
houseSalesDF.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#DataFrame for Float variables
housesFloat = houseSalesDF.select_dtypes(include=['float64'])
housesFloat
# Out:
#           price  bathrooms  sqft_living  sqft_lot  floors      lat     long
# 0      221900.0       1.00       1180.0    5650.0     1.0  47.5112 -122.257
# 1      538000.0       2.25       2570.0    7242.0     2.0  47.7210 -122.319
# 2      180000.0       1.00        770.0   10000.0     1.0  47.7379 -122.233
# 3      604000.0       3.00       1960.0    5000.0     1.0  47.5208 -122.393
# 4      510000.0       2.00       1680.0    8080.0     1.0  47.6168 -122.045
# ...         ...        ...          ...       ...     ...      ...      ...
# 21608  360000.0       2.50       1530.0    1131.0     3.0  47.6993 -122.346
# 21609  400000.0       2.50       2310.0    5813.0     2.0  47.5107 -122.362
# 21610  402101.0       0.75       1020.0    1350.0     2.0  47.5944 -122.299
# 21611  400000.0       2.50       1600.0    2388.0     2.0  47.5345 -122.069
# 21612  325000.0       0.75       1020.0    1076.0     2.0  47.5941 -122.299
#
# [17618 rows x 7 columns]

# %%
#Loop through attributes to display histograms and id outliers
for attribute in housesFloat.columns:
    sns.set(style="ticks")

    fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                    gridspec_kw={"height_ratios": (.20, .80)}, figsize = (12, 8))

    sns.boxplot(x= housesFloat[attribute], ax=ax_box)
    sns.histplot(x = housesFloat[attribute], ax=ax_hist, kde=True)
    

    ax_box.set(yticks=[])
    sns.despine(ax=ax_hist)
    sns.despine(ax=ax_box, left=True)

# %% [markdown]
# ### Fixing the outliers

# %%
# Using box plots or z score to detect the outliers

# %%
# Extract year, month, and month year from the date
houseSalesDF["Year"] = pd.DatetimeIndex(houseSalesDF["date"]).year
houseSalesDF["Month"] = pd.DatetimeIndex(houseSalesDF["date"]).month
houseSalesDF['Month_Year'] = pd.to_datetime(houseSalesDF['date']).dt.to_period('M')
houseSalesDF.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00       1180.0    5650.0     1.0
# 1 2014-12-09  538000.0         3       2.25       2570.0    7242.0     2.0
# 2 2015-02-25  180000.0         2       1.00        770.0   10000.0     1.0
# 3 2014-12-09  604000.0         4       3.00       1960.0    5000.0     1.0
# 4 2015-02-18  510000.0         3       2.00       1680.0    8080.0     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
# 2           0     0          3  ...      1933             0    98028  47.7379
# 3           0     0          5  ...      1965             0    98136  47.5208
# 4           0     0          3  ...      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15  Year  Month  Month_Year
# 0 -122.257           1340        5650  2014     10     2014-10
# 1 -122.319           1690        7639  2014     12     2014-12
# 2 -122.233           2720        8062  2015      2     2015-02
# 3 -122.393           1360        5000  2014     12     2014-12
# 4 -122.045           1800        7503  2015      2     2015-02
#
# [5 rows x 23 columns]

# %%
sqft = houseSalesDF.loc[:,['sqft_living','sqft_lot','sqft_living15','sqft_lot15']]
sqft
# Out:
#        sqft_living  sqft_lot  sqft_living15  sqft_lot15
# 0           1180.0    5650.0           1340        5650
# 1           2570.0    7242.0           1690        7639
# 2            770.0   10000.0           2720        8062
# 3           1960.0    5000.0           1360        5000
# 4           1680.0    8080.0           1800        7503
# ...            ...       ...            ...         ...
# 21608       1530.0    1131.0           1530        1509
# 21609       2310.0    5813.0           1830        7200
# 21610       1020.0    1350.0           1020        2007
# 21611       1600.0    2388.0           1410        1287
# 21612       1020.0    1076.0           1020        1357
#
# [17618 rows x 4 columns]

# %%
# what is the difference between sqft_living
sns.scatterplot(data=sqft, x=sqft['sqft_living'], y=sqft['sqft_living15'])

# %%
sns.scatterplot(data=sqft, x=sqft['sqft_lot'], y=sqft['sqft_lot15'])

# %%
sqft.corr()
# Out:
#                sqft_living  sqft_lot  sqft_living15  sqft_lot15
# sqft_living       1.000000  0.165686       0.757712    0.181731
# sqft_lot          0.165686  1.000000       0.141718    0.722983
# sqft_living15     0.757712  0.141718       1.000000    0.183964
# sqft_lot15        0.181731  0.722983       0.183964    1.000000

# %%
# Plotting Price rate versus month
month_year_group = houseSalesDF.groupby("Month_Year")['price'].sum().plot(legend=True)

# %% [markdown]
# Why we see a huge spike after Jan 2015 and lower prices after April 2015?

# %%
# Plot correlation Matrix Index
corr = houseSalesDF.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col1 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col2 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col3 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col4 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col5 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col6 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col7 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col8 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col9 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col10 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col11 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col12 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col13 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col14 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col15 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col16 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col17 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col18 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col19 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row0_col20 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col0 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col2 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col3 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col5 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col6 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col7 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col8 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col9 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col10 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col11 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col12 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col13 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col14 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col15 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col16 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col17 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col18 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col19 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row1_col20 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col0 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col1 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col3 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col4 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col5 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col6 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col7 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col8 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col9 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col10 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col11 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col12 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col13 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col14 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col15 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col16 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_3ad00750_aa14_11ec_ba1a_dca90498c711row2_col17 {
#             background-color:  #f7b89c;

# %% [markdown]
# As we can understand from the correlation matrix index, there is a significant association between the variables, that they have a darker box. Red box and light red is the indication of positive correlation, and blue and light blue is an indication of negative correlation.

# %% [markdown]
# ### Correlation between price and different columns

# %%
# Let's find out the correlation between price and other values
price_corr = houseSalesDF.corr()["price"].sort_values(ascending=False)
price_corrdf = price_corr.reset_index(name="corr")
price_corrdf.head(10)
# Out:
#            index      corr
# 0          price  1.000000
# 1    sqft_living  0.705356
# 2          grade  0.670242
# 3     sqft_above  0.607853
# 4  sqft_living15  0.589529
# 5      bathrooms  0.528322
# 6           view  0.404474
# 7  sqft_basement  0.324357
# 8            lat  0.308308
# 9       bedrooms  0.308095

# %%
# high correlation is between 0.7 - 1.0
high_price_corr = price_corrdf[price_corrdf["corr"] > 0.7]
high_price_corr.rename(columns={'index':'attribute'})
# Out:
#      attribute      corr
# 0        price  1.000000
# 1  sqft_living  0.705356

# %%
# Moderate correlation is between 0.5 - 0.7
moderate_price_corr = price_corrdf[(price_corrdf["corr"]>0.5) & (price_corrdf['corr']<0.7)]
moderate_price_corr.rename(columns={'index':'attribute'})
# Out:
#        attribute      corr
# 2          grade  0.670242
# 3     sqft_above  0.607853
# 4  sqft_living15  0.589529
# 5      bathrooms  0.528322

# %%
# Weak correlation is between 0.0 - 0.5
weak_price_corr = price_corrdf[(price_corrdf['corr']<0.5) & (price_corrdf['corr']>0)]
weak_price_corr.rename(columns={'index':'attribute'})
# Out:
#         attribute      corr
# 6            view  0.404474
# 7   sqft_basement  0.324357
# 8             lat  0.308308
# 9        bedrooms  0.308095
# 10     waterfront  0.283986
# 11         floors  0.260248
# 12   yr_renovated  0.127612
# 13       sqft_lot  0.088484
# 14     sqft_lot15  0.082180
# 15       yr_built  0.054736
# 16      condition  0.033073
# 17           long  0.022692
# 18           Year  0.001920

# %%
# negative correlation is less than 0
negative_price_corr = price_corrdf[price_corrdf['corr'] < 0]
negative_price_corr.rename(columns={'index':'attribute'})
# Out:
#    attribute      corr
# 19     Month -0.009578
# 20   zipcode -0.052410
